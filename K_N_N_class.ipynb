# %% [markdown]
# # KNN Glass Classification Notebook
#
# _Converted automatically from `K_N_N_class.py` on 2025-08-25 03:01:27_
#
# > Note: This notebook preserves your original script in a single code cell below.
# You can split it into multiple cells later if you like.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn.model_selection import GridSearchCV

df = pd.read_csv('glass.csv')
print(df.head())

X=df.iloc[:,:8]
y=df['Type']

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=0)

from sklearn.neighbors import KNeighborsClassifier
n=KNeighborsClassifier(n_neighbors=1,metric='euclidean')
n.fit(X_train,y_train)
y_pred=n.predict(X_test)
print(y_pred)
print('accuracy',metrics.accuracy_score(y_test,y_pred))

#optimum k value

error_rate = []
for i in range(1,40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
plt.show()


#hyperparameter tuning

leaf_size = list(range(1,50))
n_neighbors = list(range(1,40))
p=[1,2]

hyperparameters = dict(leaf_size=leaf_size, n_neighbors=n_neighbors, p=p)
n_2 = KNeighborsClassifier()
clf = GridSearchCV(n_2, hyperparameters, cv=5)
best_value = clf.fit(X_train,y_train)
print('Best leaf_size:', best_value.best_estimator_.get_params()['leaf_size'])
print('Best p:', best_value.best_estimator_.get_params()['p'])
print('Best n_neighbors:', best_value.best_estimator_.get_params()['n_neighbors'])


from sklearn import metrics
print('Mean absolute error:',metrics.mean_absolute_error(y_test,y_pred))
print('Mean squared error:',metrics.mean_squared_error(y_test,y_pred))
print('Root Mean squared error:',np.sqrt(metrics.mean_squared_error(y_test,y_pred)))


a = float(input('enter the RI :'))
b = float(input('enter the Na :'))
c = float(input('enter work Mg :'))
d = float(input('enter work Al :'))
e = float(input('enter work Si :'))
f = float(input('enter work K :'))
g = float(input('enter work Ca :'))
h = float(input('enter work Ba :'))
h = float(input('enter work Fe :'))

testX = [[a,b,c,d,e,f,g,h]]
testp = n.predict(testX)
print('Glasstype',testp)
